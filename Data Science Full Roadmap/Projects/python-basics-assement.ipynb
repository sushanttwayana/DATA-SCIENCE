# %% [markdown]
# ![image.png](attachment:ec61fc8e-4d63-4a0a-8a8a-0790ecc73894.png)

# %% [markdown]
# ![image.png](attachment:7d4abfda-b3be-439a-97c6-500aa125bb0c.png)

# %% [markdown]
# ![image.png](attachment:82825820-ea67-4d1b-b930-95c3c31e0bf8.png)

# %% [markdown]
# ![image.png](attachment:89bbe1a4-e4e5-442b-9444-d6e2fc9311ea.png)

# %% [markdown]
# ![image.png](attachment:c5d33e1d-ad38-459a-a78f-cda0c70a96e8.png)

# %% [markdown]
# ![image.png](attachment:82f8aa09-d709-42c3-917d-327389c0a9ec.png)

# %% [markdown]
# ![image.png](attachment:b578a766-aa68-43d3-b4e5-d4189d72ff1d.png)

# %% [markdown]
# ![image.png](attachment:98f64e66-80d1-430e-8c9c-1f5a86939e19.png)

# %% [markdown]
# ![image.png](attachment:d1d3f0f3-213d-40b0-be82-019c9c55ce85.png)

# %% [markdown]
# ![image.png](attachment:1ff8b684-c1c6-474e-bcc6-1472c4394e18.png)

# %% [markdown]
# ![image.png](attachment:9af0a988-cf78-41ef-b28f-0053104c3e46.png)

# %% [markdown]
# ![image.png](attachment:367b107f-9867-4ee7-9c0d-dcf5d907de13.png)

# %% [markdown]
# ![image.png](attachment:4e98aaf0-f1f8-4509-94b0-5f7e3dbbbf97.png)

# %% [markdown]
# ![image.png](attachment:16da4b37-db1d-4d59-b1cf-e3aec3ad3cbb.png)

# %% [markdown]
# ![image.png](attachment:b041b158-47b6-4e45-8114-076591306332.png)
