# %% [markdown]
# ![image.png](attachment:5b9df86c-26d5-457f-b661-1ae4e681eed2.png)

# %% [markdown]
# ![image.png](attachment:bbe55fcf-3388-4e52-89b6-d176f2fc0222.png)

# %% [markdown]
# ![image.png](attachment:6c6b4cf4-24e8-4f86-9a84-00877bdaef57.png)

# %% [markdown]
# ![image.png](attachment:31644d11-4819-495d-9527-7952ff52c332.png)

# %% [markdown]
# ![image.png](attachment:229ebcde-56f2-4827-b014-006816038fda.png)

# %% [markdown]
# ![image.png](attachment:fec75cd3-1b72-490f-9082-8f038e6bb2d6.png)

# %% [markdown]
# ![image.png](attachment:ead3e680-1bf8-4f65-876e-5ff576fd8295.png)

# %% [markdown]
# ![image.png](attachment:0ef4f40f-7e90-43d6-a908-f04e37321ea4.png)

# %% [markdown]
# ![image.png](attachment:5674aaa8-94df-444b-9598-642425f74b8a.png)

# %% [markdown]
# ![image.png](attachment:5d56fa5f-188f-4746-ad54-fc81937b8e26.png)

# %% [markdown]
# ![image.png](attachment:4871bfe5-8b0f-4204-ba64-a5c69c63e067.png)

# %% [markdown]
# ![image.png](attachment:ff4d7fe2-078f-405b-96b9-04502a952f3e.png)

# %% [markdown]
# ![image.png](attachment:11af1d34-8cee-403e-b5e4-c4e038f9de74.png)

# %% [markdown]
# ![image.png](attachment:a09191b6-e84c-46dd-a002-a966062ec941.png)

# %% [markdown]
# ![image.png](attachment:b32b41cd-3070-4943-90e6-0382384be5a2.png)
