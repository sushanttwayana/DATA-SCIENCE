# %% [markdown]
# ![image.png](attachment:343a33fb-d449-4fca-a0ca-efc0bafde588.png)

# %% [markdown]
# ![image.png](attachment:78a6cfe1-b02b-4213-8979-08a912c89523.png)

# %% [markdown]
# ![image.png](attachment:3b277029-f5fa-4579-8479-a5f0e54bcffe.png)

# %% [markdown]
# ![image.png](attachment:261bbc91-011f-4c6a-a033-d90932d085c4.png)

# %% [markdown]
# ![image.png](attachment:d2d985e9-c3cf-4398-8d53-1c85970f07bd.png)

# %% [markdown]
# ![image.png](attachment:48d776cd-a125-467c-9553-9fbe7c802486.png)

# %% [markdown]
# ![image.png](attachment:4b43c8d9-ba0b-4c4a-850d-6d1b075eff90.png)

# %% [markdown]
# ![image.png](attachment:828f113b-87a1-43f1-9d41-b855d7369f44.png)

# %% [markdown]
# ![image.png](attachment:809afd75-1c0d-4208-91e2-f03c7ca69a54.png)

# %% [markdown]
# ![image.png](attachment:7eedad1c-f030-4f7e-8e56-ffaf3eded4b5.png)

# %% [markdown]
# ![image.png](attachment:40c8882a-b0ed-497b-bde2-7701a624e138.png)

# %% [markdown]
# ![image.png](attachment:27b236ad-256f-44fe-b9e6-17dcf5a3a12b.png)

# %% [markdown]
# ![image.png](attachment:1a551ef3-a1ea-4f18-ad79-efff23234cfc.png)

# %% [markdown]
# ![image.png](attachment:d1f286de-7b49-4160-acb1-2e34eec3ed18.png)

# %% [markdown]
# ![image.png](attachment:b1b113ab-1eaf-4b63-ad9a-cd581dfb51c7.png)
