# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing DateTime data
#
# You'll now work with the entire divorce dataset! The data describes Mexican marriages dissolved between 2000 and 2015. It contains marriage and divorce dates, education level, birthday, income for each partner, and marriage duration, as well as the number of children the couple had at the time of divorce.
#
# The column names and data types are as follows:
#
# divorce_date          object
# dob_man               object
# education_man         object
# income_man           float64
# dob_woman             object
# education_woman       object
# income_woman         float64
# marriage_date         object
# marriage_duration    float64
# num_kids             float64
# It looks like there is a lot of date information in this data that is not yet a DateTime data type! Your task is to fix that so that you can explore patterns over time.
#
#
# * Import divorce.csv, saving as a DataFrame, divorce; indicate in the import function that the divorce_date, dob_man, dob_woman, and marriage_date columns should be imported as DateTime values

# %%
divorces1 = pd.read_csv("/kaggle/input/divorcemarriage-dataset-with-birth-dates/divorces_2000-2015_translated.csv")
divorces1.head()
# Out:
#   Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 0       9/6/06       Necesario                MEXICANA        18/12/75
# 1       1/2/00      Voluntario                MEXICANA             NaN
# 2       1/2/05       Necesario                MEXICANA         22/2/55
# 3       1/2/06       Necesario                MEXICANA         20/1/64
# 4       1/2/06       Necesario                MEXICANA        30/10/75
#
#   Place_of_birth_partner_man Birth_municipality_of_partner_man  \
# 0          XALAPA - ENRIQUEZ                            XALAPA
# 1                        NaN                               NaN
# 2          XALAPA - ENRIQUEZ                            XALAPA
# 3          XALAPA - ENRIQUEZ                            XALAPA
# 4          XALAPA - ENRIQUEZ                            XALAPA
#
#   Birth_federal_partner_man Birth_country_partner_man  Age_partner_man  \
# 0                  VERACRUZ                    MEXICO             30.0
# 1                       NaN                       NaN             47.0
# 2                  VERACRUZ                    MEXICO             49.0
# 3                  VERACRUZ                    MEXICO             42.0
# 4                  VERACRUZ                    MEXICO             30.0
#
#   Residence_municipality_partner_man  ... Marriage_certificate_municipality  \
# 0                             XALAPA  ...                            XALAPA
# 1                                NaN  ...                            XALAPA
# 2                                NaN  ...                            XALAPA
# 3                             XALAPA  ...                            XALAPA
# 4                           COATEPEC  ...                            XALAPA
#
#   Marriage_certificate_federal  Level_of_education_partner_man  \
# 0                     VERACRUZ                      SECUNDARIA
# 1                     VERACRUZ                    PREPARATORIA
# 2                     VERACRUZ                    PREPARATORIA
# 3                     VERACRUZ                     PROFESIONAL
# 4                     VERACRUZ                     PROFESIONAL
#
#   Employment_status_partner_man Level_of_education_partner_woman  \
# 0                        OBRERO                       SECUNDARIA
# 1               ESTABLECIMIENTO                     PREPARATORIA
# 2                        OBRERO                              NaN
# 3                      EMPLEADO                     PREPARATORIA
# 4                      EMPLEADO                     PREPARATORIA
#
#                 Employment_status_partner_woman Marriage_duration  \
# 0                                      EMPLEADO               5.0
# 1                                      EMPLEADO               NaN
# 2  TRABAJADOR POR CUENTA PROPIA EN VIA PUBLICA                NaN
# 3                                      EMPLEADO              18.0
# 4                                    NO TRABAJA               7.0
#
#   Marriage_duration_months Num_Children Custody
# 0                      NaN          1.0     NaN
# 1                      NaN          NaN     NaN
# 2                      NaN          NaN     NaN
# 3                      NaN          2.0   MADRE
# 4                      NaN          2.0   MADRE
#
# [5 rows x 41 columns]

# %%
print(divorces1.columns.to_list())
# Out:
# ['Divorce_date', 'Type_of_divorce', 'Nationality_partner_man', 'DOB_partner_man', 'Place_of_birth_partner_man', 'Birth_municipality_of_partner_man', 'Birth_federal_partner_man', 'Birth_country_partner_man', 'Age_partner_man', 'Residence_municipality_partner_man', 'Residence_federal_partner_man', 'Residence_country_partner_man', 'Monthly_income_partner_man_peso', 'Occupation_partner_man', 'Place_of_residence_partner_man', 'Nationality_partner_woman', 'DOB_partner_woman', 'DOB_registration_date_partner_woman', 'Place_of_birth_partner_woman', 'Birth_municipality_of_partner_woman', 'Birth_federal_partner_woman', 'Birth_country_partner_woman', 'Age_partner_woman', 'Place_of_residence_partner_woman', 'Residence_municipality_partner_woman', 'Residence_federal_partner_woman', 'Residence_country_partner_woman', 'Occupation_partner_woman', 'Monthly_income_partner_woman_peso', 'Date_of_marriage', 'Marriage_certificate_place', 'Marriage_certificate_municipality', 'Marriage_certificate_federal', 'Level_of_education_partner_man', 'Employment_status_partner_man', 'Level_of_education_partner_woman', 'Employment_status_partner_woman', 'Marriage_duration', 'Marriage_duration_months', 'Num_Children', 'Custody']

# %%
# Import divorce.csv, parsing the appropriate columns as dates in the import
divorce = pd.read_csv("/kaggle/input/divorcemarriage-dataset-with-birth-dates/divorces_2000-2015_translated.csv",\
                      parse_dates =["Divorce_date","DOB_partner_man","DOB_partner_woman","Date_of_marriage"])
print(divorce.dtypes)
# Out:
# /tmp/ipykernel_30/1655484721.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   divorce = pd.read_csv("/kaggle/input/divorcemarriage-dataset-with-birth-dates/divorces_2000-2015_translated.csv",\
# /tmp/ipykernel_30/1655484721.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   divorce = pd.read_csv("/kaggle/input/divorcemarriage-dataset-with-birth-dates/divorces_2000-2015_translated.csv",\
# /tmp/ipykernel_30/1655484721.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   divorce = pd.read_csv("/kaggle/input/divorcemarriage-dataset-with-birth-dates/divorces_2000-2015_translated.csv",\
# /tmp/ipykernel_30/1655484721.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   divorce = pd.read_csv("/kaggle/input/divorcemarriage-dataset-with-birth-dates/divorces_2000-2015_translated.csv",\
# Divorce_date                            datetime64[ns]
# Type_of_divorce                                 object
# Nationality_partner_man                         object
# DOB_partner_man                         datetime64[ns]
# Place_of_birth_partner_man                      object
# Birth_municipality_of_partner_man               object
# Birth_federal_partner_man                       object
# Birth_country_partner_man                       object
# Age_partner_man                                float64
# Residence_municipality_partner_man              object
# Residence_federal_partner_man                   object
# Residence_country_partner_man                   object
# Monthly_income_partner_man_peso                float64
# Occupation_partner_man                          object
# Place_of_residence_partner_man                  object
# Nationality_partner_woman                       object
# DOB_partner_woman                       datetime64[ns]
# DOB_registration_date_partner_woman             object
# Place_of_birth_partner_woman                    object
# Birth_municipality_of_partner_woman             object
# Birth_federal_partner_woman                     object
# Birth_country_partner_woman                     object
# Age_partner_woman                              float64
# Place_of_residence_partner_woman                object
# Residence_municipality_partner_woman            object
# Residence_federal_partner_woman                 object
# Residence_country_partner_woman                 object
# Occupation_partner_woman                        object
# Monthly_income_partner_woman_peso              float64
# Date_of_marriage                        datetime64[ns]
# Marriage_certificate_place                      object
# Marriage_certificate_municipality               object
# Marriage_certificate_federal                    object
# Level_of_education_partner_man                  object
# Employment_status_partner_man                   object
# Level_of_education_partner_woman                object
# Employment_status_partner_woman                 object
# Marriage_duration                              float64
# Marriage_duration_months                       float64
# Num_Children                                   float64
# Custody                                         object
# dtype: object

# %% [markdown]
# Bingo! Nice work parsing those dates at the same time as you imported the data into pandas. Next, have a go at updating DateTime data types in a DataFrame that has already been imported!

# %% [markdown]
# **Updating data type to DateTime**
#
# Now, the divorce DataFrame has been loaded for you, but one column is stored as a string that should be DateTime data. Which one is it? Once you've identified the column, you'll update it so that you can explore it more closely in the next exercise.
#
#
# * Convert the marriage_date column of the divorce DataFrame to DateTime values.

# %%
# Convert the marriage_date column to DateTime values
divorce["Date_of_marriage"] = pd.to_datetime(divorce["Date_of_marriage"])

# %% [markdown]
# **Visualizing relationships over time**
#
# Now that your date data is saved as DateTime data, you can explore patterns over time! Does the year that a couple got married have a relationship with the number of children that the couple has at the time of divorce? Your task is to find out!
#
# The divorce DataFrame (with all dates formatted as DateTime data types) has been loaded for you. pandas has been loaded as pd, matplotlib.pyplot has been loaded as plt, and Seaborn has been loaded as sns.
#
#
# * Define a column called marriage_year, which contains just the year portion of the marriage_date column.
# * Create a line plot showing the average number of kids a couple had during their marriage, arranged by the year that the couple got married.

# %%
print(divorce["Date_of_marriage"])
# Out:
# 0      2000-06-26
# 1      1977-02-17
# 2      1975-12-18
# 3      1987-03-12
# 4      1998-11-14
#           ...
# 4918   2008-10-25
# 4919   2012-05-26
# 4920   1978-02-06
# 4921   1979-05-11
# 4922   2009-08-22
# Name: Date_of_marriage, Length: 4923, dtype: datetime64[ns]

# %%
# Define the marriage_year column
divorce["Divorce_year"] = divorce["Divorce_date"].dt.year
print(divorce["Divorce_year"])
# Out:
# 0       2006
# 1       2000
# 2       2005
# 3       2006
# 4       2006
#         ...
# 4918    2012
# 4919    2013
# 4920    2013
# 4921    2012
# 4922    2013
# Name: Divorce_year, Length: 4923, dtype: int32

# %%
# Replace NaN values with 0 in the 'Num_Children' column
divorce["Num_Children"] = divorce["Num_Children"].fillna(0)

# Print the updated 'Num_Children' column to verify
print(divorce["Num_Children"])
# Out:
# 0       1.0
# 1       0.0
# 2       0.0
# 3       2.0
# 4       2.0
#        ...
# 4918    0.0
# 4919    0.0
# 4920    2.0
# 4921    2.0
# 4922    0.0
# Name: Num_Children, Length: 4923, dtype: float64

# %%
# Create a line plot showing the average number of kids by year
sns.lineplot(data=divorce, x="Divorce_year", y="Num_Children")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Visualizing variable relationships
#
# In the last exercise, you may have noticed that a longer marriage_duration is correlated with having more children, represented by the num_kids column. The correlation coefficient between the marriage_duration and num_kids variables is 0.45.
#
# In this exercise, you'll create a scatter plot to visualize the relationship between these variables. pandas has been loaded as pd, matplotlib.pyplot has been loaded as plt, and Seaborn has been loaded as sns. The dataset name is divorce.
#
#
# * Create a scatterplot showing marriage_duration on the x-axis and num_kids on the y-axis.

# %%
divorce.tail()
# Out:
#      Divorce_date Type_of_divorce Nationality_partner_man DOB_partner_man  \
# 4918   2012-10-31      Voluntario                MEXICANA      1977-10-29
# 4919   2013-10-31      Voluntario                MEXICANA      1982-10-11
# 4920   2013-10-31      Voluntario                MEXICANA      2054-10-28
# 4921   2012-12-31      Voluntario                MEXICANA      2058-07-02
# 4922   2013-12-31      Voluntario                MEXICANA      2060-06-22
#
#      Place_of_birth_partner_man Birth_municipality_of_partner_man  \
# 4918                    MORELIA                           MORELIA
# 4919                   VERACRUZ                          VERACRUZ
# 4920          XALAPA - ENRIQUEZ                            XALAPA
# 4921                 TLAPACOYAN                        TLAPACOYAN
# 4922                TLACOTALPAN                       TLACOTALPAN
#
#      Birth_federal_partner_man Birth_country_partner_man  Age_partner_man  \
# 4918                 MICHOACAN                    MEXICO             35.0
# 4919                  VERACRUZ                    MEXICO             30.0
# 4920                  VERACRUZ                    MEXICO             59.0
# 4921                  VERACRUZ                    MEXICO             54.0
# 4922                  VERACRUZ                    MEXICO             53.0
#
#      Residence_municipality_partner_man  ... Marriage_certificate_federal  \
# 4918                            MORELIA  ...                     VERACRUZ
# 4919                             XALAPA  ...                     VERACRUZ
# 4920                    EMILIANO ZAPATA  ...                     VERACRUZ
# 4921                             XALAPA  ...                     VERACRUZ
# 4922                             XALAPA  ...                     VERACRUZ
#
#      Level_of_education_partner_man  Employment_status_partner_man  \
# 4918                    PROFESIONAL                       EMPLEADO
# 4919                    PROFESIONAL                       EMPLEADO
# 4920                    PROFESIONAL                       EMPLEADO
# 4921                   PREPARATORIA                            NaN
# 4922                    PROFESIONAL                       EMPLEADO
#
#      Level_of_education_partner_woman Employment_status_partner_woman  \
# 4918                      PROFESIONAL                        EMPLEADO
# 4919                      PROFESIONAL                        EMPLEADO
# 4920                      PROFESIONAL                        EMPLEADO
# 4921                         PRIMARIA                      NO TRABAJA
# 4922                      PROFESIONAL                        EMPLEADO
#
#      Marriage_duration Marriage_duration_months Num_Children Custody  \
# 4918               3.0                     11.0          0.0     NaN
# 4919               1.0                      NaN          0.0     NaN
# 4920              35.0                      NaN          2.0     NaN
# 4921              33.0                      NaN          2.0     NaN
# 4922               4.0                      NaN          0.0     NaN
#
#      Divorce_year
# 4918         2012
# 4919         2013
# 4920         2013
# 4921         2012
# 4922         2013
#
# [5 rows x 42 columns]

# %%
# Create the scatterplot
sns.scatterplot(x="Marriage_duration", y="Num_Children", data = divorce)
plt.show()

# %% [markdown]
# Bingo! There is a slight positive relationship in your scatterplot. In the dataset, couples with no children have no value in the num_kids column. If you are confident that all or most of the missing values in num_kids are related to couples without children, you could consider updating these values to 0, which might increase the correlation

# %% [markdown]
# **Visualizing multiple variable relationships**
#
# Seaborn's .pairplot() is excellent for understanding the relationships between several or all variables in a dataset by aggregating pairwise scatter plots in one visual.
#
# Your task is to use a pairplot to compare the relationship between marriage_duration and income_woman. pandas has been loaded as pd, matplotlib.pyplot has been loaded as plt, and Seaborn has been loaded as sns.
#
#
# * Create a pairplot to visualize the relationships between income_woman and marriage_duration in the divorce DataFrame.

# %%
# Increase plot size by adjusting height and aspect
sns.pairplot(data=divorce, vars=["Monthly_income_partner_woman_peso", "Marriage_duration"], 
             height=3, aspect=2)  # height controls the height of each facet, aspect controls width

# Display the plot
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Well done! Just as in the correlation matrix, you can see that the relationship between income_woman and marriage_duration is not a strong one. You can also get a sense of the distributions of both variables in the upper left and lower right plots.**

# %% [markdown]
# # Categorical data in scatter plots
#
# In the video, we explored how men's education and age at marriage related to other variables in our dataset, the divorce DataFrame. Now, you'll take a look at how women's education and age at marriage relate to other variables!
#
# Your task is to create a scatter plot of each woman's age and income, layering in the categorical variable of education level for additional context.
#
#
# * Create a scatter plot that shows woman_age_marriage on the x-axis and income_woman on the y-axis; each data point should be colored based on the woman's level of education, represented by education_woman.

# %%
print(divorce.dtypes)
# Out:
# Divorce_date                            datetime64[ns]
# Type_of_divorce                                 object
# Nationality_partner_man                         object
# DOB_partner_man                         datetime64[ns]
# Place_of_birth_partner_man                      object
# Birth_municipality_of_partner_man               object
# Birth_federal_partner_man                       object
# Birth_country_partner_man                       object
# Age_partner_man                                float64
# Residence_municipality_partner_man              object
# Residence_federal_partner_man                   object
# Residence_country_partner_man                   object
# Monthly_income_partner_man_peso                float64
# Occupation_partner_man                          object
# Place_of_residence_partner_man                  object
# Nationality_partner_woman                       object
# DOB_partner_woman                       datetime64[ns]
# DOB_registration_date_partner_woman             object
# Place_of_birth_partner_woman                    object
# Birth_municipality_of_partner_woman             object
# Birth_federal_partner_woman                     object
# Birth_country_partner_woman                     object
# Age_partner_woman                              float64
# Place_of_residence_partner_woman                object
# Residence_municipality_partner_woman            object
# Residence_federal_partner_woman                 object
# Residence_country_partner_woman                 object
# Occupation_partner_woman                        object
# Monthly_income_partner_woman_peso              float64
# Date_of_marriage                        datetime64[ns]
# Marriage_certificate_place                      object
# Marriage_certificate_municipality               object
# Marriage_certificate_federal                    object
# Level_of_education_partner_man                  object
# Employment_status_partner_man                   object
# Level_of_education_partner_woman                object
# Employment_status_partner_woman                 object
# Marriage_duration                              float64
# Marriage_duration_months                       float64
# Num_Children                                   float64
# Custody                                         object
# Divorce_year                                     int32
# dtype: object

# %%
divorce["woman_age_marriage"] = divorce["Date_of_marriage"] - divorce["DOB_partner_woman"]
divorce["woman_age_marriage"] = divorce["woman_age_marriage"].dt.days / 365.25  # Approximation to account for leap years
# print(divorce["woman_age_marriage"])


divorce["woman_age_marriage"] = divorce["woman_age_marriage"].apply(lambda x: x if x >= 0 else None)
divorce["woman_age_marriage"].isna().sum()  # To see how many missing values you have
print(divorce["woman_age_marriage"])
# Out:
# 0       16.903491
# 1             NaN
# 2             NaN
# 3             NaN
# 4       20.087611
#           ...
# 4918    29.900068
# 4919    30.729637
# 4920          NaN
# 4921          NaN
# 4922          NaN
# Name: woman_age_marriage, Length: 4923, dtype: float64

# %%
# Create the scatter plot
sns.scatterplot(data=divorce, y="Monthly_income_partner_woman_peso", x="Age_partner_woman", hue="Level_of_education_partner_woman")
plt.show()

# %% [markdown]
# Awesome—it looks like there is a positive correlation between professional education and higher salaries, as you might expect. The relationship between women's age at marriage and education level is a little less clear.

# %% [markdown]
# # Exploring with KDE plots
#
# Kernel Density Estimate (KDE) plots are a great alternative to histograms when you want to show multiple distributions in the same visual.
#
# Suppose you are interested in the relationship between marriage duration and the number of kids that a couple has. Since values in the num_kids column range only from one to five, you can plot the KDE for each value on the same plot.
#
# Recall that the num_kids column in divorce lists only N/A values for couples with no children, so you'll only be looking at distributions for divorced couples with at least one child.
#
#
# * Create a KDE plot that shows marriage_duration on the x-axis and a different colored line for each possible number of children that a couple might have, represented by num_kids

# %%
# Create the KDE plot
sns.kdeplot(data =divorce, x ="Marriage_duration", hue="Num_Children")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /tmp/ipykernel_30/2354687822.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data =divorce, x ="Marriage_duration", hue="Num_Children")
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# * Notice that the plot currently shows marriage durations less than zero; update the KDE plot so that marriage duration cannot be smoothed past the extreme data points.

# %%
# Update the KDE plot so that marriage duration can't be smoothed too far
sns.kdeplot(data=divorce, x="Marriage_duration", hue="Num_Children", cut=0)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /tmp/ipykernel_30/3257569074.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=divorce, x="Marriage_duration", hue="Num_Children", cut=0)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# * Update the code for the KDE plot from the previous step to show a cumulative distribution function for each number of children a couple has.

# %%
# Update the KDE plot to show a cumulative distribution function
sns.kdeplot(data=divorce, x="Marriage_duration", hue="Num_Children", cut=0, cumulative = True)
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /tmp/ipykernel_30/2731216691.py:2: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=divorce, x="Marriage_duration", hue="Num_Children", cut=0, cumulative = True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# Well done! It looks as though there is a positive correlation between longer marriages and more children, but of course, this doesn't indicate causation. You can also see that there is much less data on couples with more than two children; this helps us understand how reliable our findings are.
