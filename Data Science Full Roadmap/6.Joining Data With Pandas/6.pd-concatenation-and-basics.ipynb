# %% [markdown]
# # Concatenation basics
#
# You have been given a few tables of data with musical track info for different albums from the metal band, Metallica. The track info comes from their Ride The Lightning, Master Of Puppets, and St. Anger albums. Try various features of the .concat() method by concatenating the tables vertically together in different ways.
#
#
# * Concatenate tracks_master, tracks_ride, and tracks_st, in that order, setting sort to True.
# * Concatenate tracks_master, tracks_ride, and tracks_st, where the index goes from 0 to n-1.
# * Concatenate tracks_master, tracks_ride, and tracks_st, showing only columns that are in all tables.

# %%
import pandas as pd

# Try specifying a different encoding
tracks_master = pd.read_csv("/kaggle/input/most-streamed-spotify-songs-2024/Most Streamed Spotify Songs 2024.csv", encoding='ISO-8859-1', index_col=0)
tracks_master.head()
# Out:
#                                               Album Name          Artist  \
# Track
# MILLION DOLLAR BABY         Million Dollar Baby - Single   Tommy Richman
# Not Like Us                                  Not Like Us  Kendrick Lamar
# i like the way you kiss me    I like the way you kiss me         Artemas
# Flowers                                 Flowers - Single     Miley Cyrus
# Houdini                                          Houdini          Eminem
#
#                            Release Date          ISRC All Time Rank  \
# Track
# MILLION DOLLAR BABY           4/26/2024  QM24S2402528             1
# Not Like Us                    5/4/2024  USUG12400910             2
# i like the way you kiss me    3/19/2024  QZJ842400387             3
# Flowers                       1/12/2023  USSM12209777             4
# Houdini                       5/31/2024  USUG12403398             5
#
#                             Track Score Spotify Streams  \
# Track
# MILLION DOLLAR BABY               725.4     390,470,936
# Not Like Us                       545.9     323,703,884
# i like the way you kiss me        538.4     601,309,283
# Flowers                           444.9   2,031,280,633
# Houdini                           423.3     107,034,922
#
#                            Spotify Playlist Count Spotify Playlist Reach  \
# Track
# MILLION DOLLAR BABY                        30,716            196,631,588
# Not Like Us                                28,113            174,597,137
# i like the way you kiss me                 54,331            211,607,669
# Flowers                                   269,802            136,569,078
# Houdini                                     7,223            151,469,874
#
#                             Spotify Popularity  ... SiriusXM Spins  \
# Track                                           ...
# MILLION DOLLAR BABY                       92.0  ...            684
# Not Like Us                               92.0  ...              3
# i like the way you kiss me                92.0  ...            536
# Flowers                                   85.0  ...          2,182
# Houdini                                   88.0  ...              1
#
#                            Deezer Playlist Count Deezer Playlist Reach  \
# Track
# MILLION DOLLAR BABY                         62.0            17,598,718
# Not Like Us                                 67.0            10,422,430
# i like the way you kiss me                 136.0            36,321,847
# Flowers                                    264.0            24,684,248
# Houdini                                     82.0            17,660,624
#
#                            Amazon Playlist Count Pandora Streams  \
# Track
# MILLION DOLLAR BABY                        114.0      18,004,655
# Not Like Us                                111.0       7,780,028
# i like the way you kiss me                 172.0       5,022,621
# Flowers                                    210.0     190,260,277
# Houdini                                    105.0       4,493,884
#
#                            Pandora Track Stations  Soundcloud Streams  \
# Track
# MILLION DOLLAR BABY                        22,931           4,818,457
# Not Like Us                                28,444           6,623,075
# i like the way you kiss me                  5,639           7,208,651
# Flowers                                   203,384                 NaN
# Houdini                                     7,006             207,179
#
#                            Shazam Counts TIDAL Popularity  Explicit Track
# Track
# MILLION DOLLAR BABY            2,669,262              NaN               0
# Not Like Us                    1,118,279              NaN               1
# i like the way you kiss me     5,285,340              NaN               0
# Flowers                       11,822,942              NaN               0
# Houdini                          457,017              NaN               1
#
# [5 rows x 28 columns]

# %%
# Try specifying a different encoding
tracks_st = pd.read_csv("/kaggle/input/-spotify-tracks-dataset/dataset.csv", encoding='ISO-8859-1', index_col=0)
tracks_st.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %%
# Try specifying a different encoding
tracks_ride = pd.read_csv("/kaggle/input/top-50-indian-singers-song-data-from-spotify/SingerAndSongs.csv", encoding='ISO-8859-1', index_col=0)
tracks_ride.head()
# Out:
#              acousticness  danceability  energy                      id  \
# Singer
# Aastha Gill       0.48500         0.770   0.824  39ujbBjTwwqUFySaCYDMMT
# Aastha Gill       0.14300         0.825   0.666  5cjVsWqIkBQC7acTRhL0RO
# Aastha Gill       0.23600         0.663   0.551  3XYvdqcZrTmRntFDDbJkJd
# Aastha Gill       0.00323         0.919   0.571  46GBoFCdFZZSjuGaZjZmGv
# Aastha Gill       0.12900         0.867   0.720  6VwVEIiCro1EMyh9B6Om3v
#
#              instrumentalness  key  liveness  loudness  mode  \
# Singer
# Aastha Gill          0.000000    1    0.3180    -6.491     0
# Aastha Gill          0.000003    4    0.2370    -4.847     0
# Aastha Gill          0.000036    3    0.0923    -8.272     0
# Aastha Gill          0.001680    5    0.1030    -7.175     0
# Aastha Gill          0.000000    9    0.2280    -5.188     0
#
#                         Song name  speechiness    tempo  \
# Singer
# Aastha Gill         Proper Patola       0.0851  172.006
# Aastha Gill              Kamariya       0.0554   96.987
# Aastha Gill  Buzz (feat. Badshah)       0.1090  113.314
# Aastha Gill           Saara India       0.0687  105.007
# Aastha Gill          Drunk n High       0.0619  104.974
#
#                                                     track_href  valence
# Singer
# Aastha Gill  https://api.spotify.com/v1/tracks/39ujbBjTwwqU...    0.490
# Aastha Gill  https://api.spotify.com/v1/tracks/5cjVsWqIkBQC...    0.763
# Aastha Gill  https://api.spotify.com/v1/tracks/3XYvdqcZrTmR...    0.601
# Aastha Gill  https://api.spotify.com/v1/tracks/46GBoFCdFZZS...    0.231
# Aastha Gill  https://api.spotify.com/v1/tracks/6VwVEIiCro1E...    0.755

# %%
# Concatenate the tracks
tracks_from_albums = pd.concat([tracks_master, tracks_ride, tracks_st],
                               sort=True)
print(tracks_from_albums.head())
# Out:
#                            AirPlay Spins                    Album Name  \
# MILLION DOLLAR BABY               40,975  Million Dollar Baby - Single
# Not Like Us                       40,778                   Not Like Us
# i like the way you kiss me        74,333    I like the way you kiss me
# Flowers                        1,474,799              Flowers - Single
# Houdini                           12,185                       Houdini
#
#                            All Time Rank  Amazon Playlist Count  \
# MILLION DOLLAR BABY                    1                  114.0
# Not Like Us                            2                  111.0
# i like the way you kiss me             3                  172.0
# Flowers                                4                  210.0
# Houdini                                5                  105.0
#
#                             Apple Music Playlist Count          Artist  \
# MILLION DOLLAR BABY                              210.0   Tommy Richman
# Not Like Us                                      188.0  Kendrick Lamar
# i like the way you kiss me                       190.0         Artemas
# Flowers                                          394.0     Miley Cyrus
# Houdini                                          182.0          Eminem
#
#                             Deezer Playlist Count Deezer Playlist Reach  \
# MILLION DOLLAR BABY                          62.0            17,598,718
# Not Like Us                                  67.0            10,422,430
# i like the way you kiss me                  136.0            36,321,847
# Flowers                                     264.0            24,684,248
# Houdini                                      82.0            17,660,624
#
#                             Explicit Track          ISRC  ... mode popularity  \
# MILLION DOLLAR BABY                    0.0  QM24S2402528  ...  NaN        NaN
# Not Like Us                            1.0  USUG12400910  ...  NaN        NaN
# i like the way you kiss me             0.0  QZJ842400387  ...  NaN        NaN
# Flowers                                0.0  USSM12209777  ...  NaN        NaN
# Houdini                                1.0  USUG12403398  ...  NaN        NaN
#
#                            speechiness tempo time_signature track_genre  \
# MILLION DOLLAR BABY                NaN   NaN            NaN         NaN
# Not Like Us                        NaN   NaN            NaN         NaN
# i like the way you kiss me         NaN   NaN            NaN         NaN
# Flowers                            NaN   NaN            NaN         NaN
# Houdini                            NaN   NaN            NaN         NaN
#
#                            track_href track_id track_name  valence
# MILLION DOLLAR BABY               NaN      NaN        NaN      NaN
# Not Like Us                       NaN      NaN        NaN      NaN
# i like the way you kiss me        NaN      NaN        NaN      NaN
# Flowers                           NaN      NaN        NaN      NaN
# Houdini                           NaN      NaN        NaN      NaN
#
# [5 rows x 51 columns]

# %%
# Concatenate the tracks so the index goes from 0 to n-1
tracks_from_albums = pd.concat([tracks_master, tracks_ride , tracks_st],
                               ignore_index = True,
                               sort=True)
print(tracks_from_albums)
# Out:
#        AirPlay Spins                    Album Name All Time Rank  \
# 0             40,975  Million Dollar Baby - Single             1
# 1             40,778                   Not Like Us             2
# 2             74,333    I like the way you kiss me             3
# 3          1,474,799              Flowers - Single             4
# 4             12,185                       Houdini             5
# ...              ...                           ...           ...
# 120826           NaN                           NaN           NaN
# 120827           NaN                           NaN           NaN
# 120828           NaN                           NaN           NaN
# 120829           NaN                           NaN           NaN
# 120830           NaN                           NaN           NaN
#
#         Amazon Playlist Count  Apple Music Playlist Count          Artist  \
# 0                       114.0                       210.0   Tommy Richman
# 1                       111.0                       188.0  Kendrick Lamar
# 2                       172.0                       190.0         Artemas
# 3                       210.0                       394.0     Miley Cyrus
# 4                       105.0                       182.0          Eminem
# ...                       ...                         ...             ...
# 120826                    NaN                         NaN             NaN
# 120827                    NaN                         NaN             NaN
# 120828                    NaN                         NaN             NaN
# 120829                    NaN                         NaN             NaN
# 120830                    NaN                         NaN             NaN
#
#         Deezer Playlist Count Deezer Playlist Reach  Explicit Track  \
# 0                        62.0            17,598,718             0.0
# 1                        67.0            10,422,430             1.0
# 2                       136.0            36,321,847             0.0
# 3                       264.0            24,684,248             0.0
# 4                        82.0            17,660,624             1.0
# ...                       ...                   ...             ...
# 120826                    NaN                   NaN             NaN
# 120827                    NaN                   NaN             NaN
# 120828                    NaN                   NaN             NaN
# 120829                    NaN                   NaN             NaN
# 120830                    NaN                   NaN             NaN
#
#                 ISRC  ... mode popularity speechiness    tempo time_signature  \
# 0       QM24S2402528  ...  NaN        NaN         NaN      NaN            NaN
# 1       USUG12400910  ...  NaN        NaN         NaN      NaN            NaN
# 2       QZJ842400387  ...  NaN        NaN         NaN      NaN            NaN
# 3       USSM12209777  ...  NaN        NaN         NaN      NaN            NaN
# 4       USUG12403398  ...  NaN        NaN         NaN      NaN            NaN
# ...              ...  ...  ...        ...         ...      ...            ...
# 120826           NaN  ...  1.0       21.0      0.0422  125.995            5.0
# 120827           NaN  ...  0.0       22.0      0.0401   85.239            4.0
# 120828           NaN  ...  0.0       22.0      0.0420  132.378            4.0
# 120829           NaN  ...  1.0       41.0      0.0297  135.960            4.0
# 120830           NaN  ...  0.0       22.0      0.0725   79.198            4.0
#
#         track_genre track_href                track_id           track_name  \
# 0               NaN        NaN                     NaN                  NaN
# 1               NaN        NaN                     NaN                  NaN
# 2               NaN        NaN                     NaN                  NaN
# 3               NaN        NaN                     NaN                  NaN
# 4               NaN        NaN                     NaN                  NaN
# ...             ...        ...                     ...                  ...
# 120826  world-music        NaN  2C3TZjDRiAzdyViavDJ217  Sleep My Little Boy
# 120827  world-music        NaN  1hIz5L4IB9hN3WRYPOCGPw     Water Into Light
# 120828  world-music        NaN  6x8ZfSoqDjuNa5SVP5QjvX       Miss Perfumado
# 120829  world-music        NaN  2e6sXL2bYv4bSz6VTdnfLs              Friends
# 120830  world-music        NaN  2hETkH7cOfqmz3LqZDHZf5            Barbincor
#
#         valence
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 120826   0.0339
# 120827   0.0350
# 120828   0.7430
# 120829   0.4130
# 120830   0.7080
#
# [120831 rows x 51 columns]

# %%
# Concatenate the tracks, show only columns names that are in all tables
tracks_from_albums = pd.concat([tracks_master, tracks_ride , tracks_st],
                               join = "inner",
                               sort=True)
print(tracks_from_albums)
# Out:
# Empty DataFrame
# Columns: []
# Index: [MILLION DOLLAR BABY, Not Like Us, i like the way you kiss me, Flowers, Houdini, Lovin On Me, Beautiful Things, Gata Only, Danza Kuduro - Cover, BAND4BAND (feat. Lil Baby), I Had Some Help (feat. Morgan Wallen), The Door, LUNCH, Like That, bathroom floor, LALA, Fortnight (feat. Post Malone), greedy, BLUE, As It Was, Paint The Town Red, Espresso, Danza Kuduro - Cover, TEXAS HOLD 'EM, Future, Beat Automotivo Tan Tan Tan Viral, STAY (with Justin Bieber), Baby Shark, we can't be friends (wait for your love), Numb / Encore, Danza Kuduro - Cover, SHEESH, Water, Strangers, Too Sweet, What's Love Got to Do with It - 2023 Remaster, A Bar Song (Tipsy), Lose Control, fukumean, Dance Monkey, BIRDS OF A FEATHER, Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½ï¿½ Spe, I'm Good (Blue), Daylight, My Love Mine All Mine, Please Please Please, Houdini, Danza Kuduro - Cover, If We Ever Broke Up, Despacito, euphoria, Panda Basi, Calm Down (with Selena Gomez), Shape of You, Mitu, Blinding Lights, Creepin' (with The Weeknd & 21 Savage), Dona Felicidade, Danza Kuduro - Cover, Unholy (feat. Kim Petras), Stereo Love - Melodic, Very Cute Melody by Marimba Tone (39813), Supernova, Me Porto Bonito, Back That Azz Up (feat. Lil Wayne & Mannie Fresh), Calm Down, CARNIVAL, Kill Bill, What Was I Made For? [From The Motion Picture "Barbie"], Babba, Heat Waves, In the End, Shakira: Bzrp Music Sessions, Vol. 53, The Way We Move - Extended Mix, Old Town Road, un x100to, Laxed ï¿½ï¿½ï¿½ Sire, Sprinter, CHIHIRO, TQG, Perfect, Pepas, Peekaboo, Ella Baila Sola, Dance The Night - From Barbie The Album, La Bebe - Remix, redrum, Easy On Me, Titï¿½ï¿½ Me Pregu, All My Life (feat. J. Cole), Anti-Hero, Quevedo: Bzrp Music Sessions, Vol. 52, Magnetic, Lollipop, La Diabla, Boy's a Liar Pt. 2, Snooze, BELLAKEO, Agora Hills, Prada, ...]
#
# [120831 rows x 0 columns]

# %% [markdown]
#  You've concatenated your first set of tables, adjusted the index, and altered the columns shown in the output. The .concat() method is a very flexible tool that is useful for combining data into a new dataset.

# %% [markdown]
# **Concatenating with keys**
#
# The leadership of the music streaming company has come to you and asked you for assistance in analyzing sales for a recent business quarter. They would like to know which month in the quarter saw the highest average invoice total. You have been given three tables with invoice data named inv_jul, inv_aug, and inv_sep. Concatenate these tables into one to create a graph of the average monthly invoice total.
#
#
# * Concatenate the three tables together vertically in order with the oldest month first, adding '7Jul', '8Aug', and '9Sep' as keys for their respective months, and save to inv_jul_thr_sep.
# * Use the .agg() method to find the average of the total column from the grouped invoices.
# * Create a bar chart of avg_inv_by_month.

# %%
# Concatenate the tables and add keys
inv_jul_thr_sep = pd.concat([inv_jul, inv_aug, inv_sep], 
                            keys=['7Jul', '8Aug', '9Sep'])

# Group the invoices by the index keys and find avg of the total column
avg_inv_by_month = inv_jul_thr_sep.groupby(level=0).agg({'total':'mean'})

# Bar plot of avg_inv_by_month
avg_inv_by_month.plot(kind='bar')
plt.show()

# %% [markdown]
# ![image.png](attachment:97780199-dfa6-463e-9269-9562cf9d9466.png)

# %% [markdown]
# Way to come through! There are many ways to write code for this task. However, concatenating the tables with a key provides a hierarchical index that can be used for grouping. Once grouped, you can average the groups and create plots. You were able to find out that September had the highest average invoice total.

# %% [markdown]
# **Concatenate and merge to find common songs**
#
# The senior leadership of the streaming service is requesting your help again. You are given the historical files for a popular playlist in the classical music genre in 2018 and 2019. Additionally, you are given a similar set of files for the most popular pop music genre playlist on the streaming service in 2018 and 2019. Your goal is to concatenate the respective files to make a large classical playlist table and overall popular music table. Then filter the classical music table using a semi join to return only the most popular classical music tracks.
#
# The tables classic_18, classic_19, and pop_18, pop_19 have been loaded for you. Additionally, pandas has been loaded as pd.
#
# * Concatenate the classic_18 and classic_19 tables vertically where the index goes from 0 to n-1, and save to classic_18_19.
# * Concatenate the pop_18 and pop_19 tables vertically where the index goes from 0 to n-1, and save to pop_18_19.
# * With classic_18_19 on the left, merge it with pop_18_19 on tid using an inner join.
# * Use .isin() to filter classic_18_19 where tid is in classic_pop.

# %%
# Concatenate the classic tables vertically
classic_18_19 = pd.concat([classic_18, classic_19], ignore_index=True)

# Concatenate the pop tables vertically
pop_18_19 = pd.concat([pop_18, pop_19], ignore_index = True)

# %% [markdown]
# ![image.png](attachment:d04b29c2-93b9-42f4-aae9-cd398ad04d09.png)
#
# Excellent work! In this exercise, you demonstrated many of the concepts discussed in this chapter, including concatenation, and semi joins. You now have experience combining data vertically and using semi- and anti joins. Time to move on to the next chapter!
